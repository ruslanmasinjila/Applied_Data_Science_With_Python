# %%
# %reset -f
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("laterite_mobilemoney_data.csv")
data.set_index(['hhid','account_num'])
# Out:
#                    account_type     weight    district  urban  gender  age  \
# hhid account_num
# 1001 1             Mobile Money  145.94444  District_A  Urban    male   32
#      2             Bank Account  145.94444  District_A  Urban    male   32
#      3             VSLA Account  145.94444  District_A  Urban    male   32
# 1002 1            SACCO Account  122.90667  District_B  Rural    male   32
#      2             VSLA Account  122.90667  District_B  Rural    male   32
# ...                         ...        ...         ...    ...     ...  ...
# 2204 1             VSLA Account  495.77039  District_C  Rural  female   58
# 2205 1             Mobile Money  666.83021  District_A  Rural  female   23
#      2             Bank Account  666.83021  District_A  Rural  female   23
#      3            SACCO Account  666.83021  District_A  Rural  female   23
#      4             VSLA Account  666.83021  District_A  Rural  female   23
#
# ...
